# %%
import os
from argparse import Namespace

# %%
os.environ["USE_TQDM_NOTEBOOK"] = "1"

# %%
from main import train_model
from inference import infer_model

# %%
if __name__ == "__main__":
    # Make a Namespace class containing arguments for training
    args = Namespace(
        cuda = True, # Un-check this if there is no CUDA-supported device
        topN = "[20]", # Use Recall@20 only for validation
        dataset = "amazon-books", 
        tst_w_val = True, # Use validation with training to predict test
        lr = 1e-4, # Learning rate
        weight_decay = 1e-5, # Model control coefficient
        batch_size = 512, # Batch size when training
        epochs = 1000,
        dims = "[1000, 1000]", # Underlying Denoising MLP model
        emb_size = 12, # Timestep-embedding, necessary for Diffusion model
        steps = 60, # Denoising steps
        noise_scale = 0.1, 
        noise_min = 1e-5,
        noise_max = 0.02,
        sampling_steps = 0, # No sampling in inference
        loss_logging = False, # Turn off epoch loss/cost results, producing clean log
        log_name = "r1"
    )
    train_model(args)
# Out:
# args: Namespace(dataset='amazon-books', data_path='./datasets/', lr=0.0001, weight_decay=1e-05, batch_size=512, infer_batch_size=0, epochs=1000, topN='[20]', tst_w_val=True, cuda=True, gpu='0', save_path='./saved_models/', log_name='r1', round=1, loss_logging=False, time_type='cat', dims='[1000, 1000]', norm=False, emb_size=12, mean_type='x0', steps=60, noise_schedule='linear-var', noise_scale=0.1, noise_min=1e-05, noise_max=0.02, sampling_noise=False, sampling_steps=0, reweight=True)
# Starting time:  2026-04-13 03:25:15
# user num: 92993
# item num: 77884
# data ready.
# models ready.
# Number of all parameters: 157861040
# Start training...
# ======================================================
# Training:   0%|          | 0/1000 [00:00<?, ?it/s]
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Epoch: 5
# Evaluating:   0%|          | 0/182 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/182 [00:00<?, ?it/s]
# [Valid]: Precision: 0.0105 Recall: 0.0578 NDCG: 0.0351 MRR: 0.0429
# [Test]: Precision: 0.0047 Recall: 0.0413 NDCG: 0.0216 MRR: 0.0212
# ------------------------------------------------------
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Epoch: 10
# Evaluating:   0%|          | 0/182 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/182 [00:00<?, ?it/s]
# [Valid]: Precision: 0.0113 Recall: 0.0631 NDCG: 0.0385 MRR: 0.0462
# [Test]: Precision: 0.005 Recall: 0.0442 NDCG: 0.0235 MRR: 0.023
# ------------------------------------------------------
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Epoch: 15
# Evaluating:   0%|          | 0/182 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/182 [00:00<?, ?it/s]
# [Valid]: Precision: 0.0039 Recall: 0.0211 NDCG: 0.0138 MRR: 0.0182
# [Test]: Precision: 0.0016 Recall: 0.0144 NDCG: 0.0083 MRR: 0.0088
# ------------------------------------------------------
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Epoch: 20
# Evaluating:   0%|          | 0/182 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/182 [00:00<?, ?it/s]
# [Valid]: Precision: 0.006 Recall: 0.0336 NDCG: 0.0212 MRR: 0.0265
# [Test]: Precision: 0.0027 Recall: 0.024 NDCG: 0.0132 MRR: 0.0133
# ------------------------------------------------------
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Epoch: 25
# Evaluating:   0%|          | 0/182 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/182 [00:00<?, ?it/s]
# [Valid]: Precision: 0.0153 Recall: 0.0858 NDCG: 0.052 MRR: 0.0612
# [Test]: Precision: 0.0067 Recall: 0.06 NDCG: 0.0317 MRR: 0.0307
# ------------------------------------------------------
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Epoch: 30
# Evaluating:   0%|          | 0/182 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/182 [00:00<?, ?it/s]
# [Valid]: Precision: 0.0157 Recall: 0.0885 NDCG: 0.0533 MRR: 0.0626
# [Test]: Precision: 0.0069 Recall: 0.062 NDCG: 0.0326 MRR: 0.0313
# ------------------------------------------------------
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Epoch: 35
# Evaluating:   0%|          | 0/182 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/182 [00:00<?, ?it/s]
# [Valid]: Precision: 0.0153 Recall: 0.0862 NDCG: 0.0528 MRR: 0.0628
# [Test]: Precision: 0.0068 Recall: 0.0607 NDCG: 0.0321 MRR: 0.0312
# ------------------------------------------------------
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Epoch: 40
# Evaluating:   0%|          | 0/182 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/182 [00:00<?, ?it/s]
# [Valid]: Precision: 0.0153 Recall: 0.0867 NDCG: 0.0528 MRR: 0.0625
# [Test]: Precision: 0.0066 Recall: 0.06 NDCG: 0.0318 MRR: 0.0308
# ------------------------------------------------------
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Epoch: 45
# Evaluating:   0%|          | 0/182 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/182 [00:00<?, ?it/s]
# [Valid]: Precision: 0.016 Recall: 0.0903 NDCG: 0.0551 MRR: 0.0655
# [Test]: Precision: 0.007 Recall: 0.0633 NDCG: 0.0336 MRR: 0.0328
# ------------------------------------------------------
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Epoch: 50
# Evaluating:   0%|          | 0/182 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/182 [00:00<?, ?it/s]
# [Valid]: Precision: 0.0159 Recall: 0.0901 NDCG: 0.0545 MRR: 0.064
# [Test]: Precision: 0.007 Recall: 0.0632 NDCG: 0.0331 MRR: 0.0317
# ------------------------------------------------------
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Epoch: 55
# Evaluating:   0%|          | 0/182 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/182 [00:00<?, ?it/s]
# [Valid]: Precision: 0.0163 Recall: 0.0924 NDCG: 0.056 MRR: 0.066
# [Test]: Precision: 0.0072 Recall: 0.0649 NDCG: 0.0343 MRR: 0.0332
# ------------------------------------------------------
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Epoch: 60
# Evaluating:   0%|          | 0/182 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/182 [00:00<?, ?it/s]
# [Valid]: Precision: 0.0165 Recall: 0.0933 NDCG: 0.0566 MRR: 0.0666
# [Test]: Precision: 0.0073 Recall: 0.0655 NDCG: 0.0345 MRR: 0.0331
# ------------------------------------------------------
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Epoch: 65
# Evaluating:   0%|          | 0/182 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/182 [00:00<?, ?it/s]
# [Valid]: Precision: 0.016 Recall: 0.0908 NDCG: 0.055 MRR: 0.0648
# [Test]: Precision: 0.0071 Recall: 0.0636 NDCG: 0.0336 MRR: 0.0325
# ------------------------------------------------------
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Epoch: 70
# Evaluating:   0%|          | 0/182 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/182 [00:00<?, ?it/s]
# [Valid]: Precision: 0.0162 Recall: 0.0913 NDCG: 0.0557 MRR: 0.0659
# [Test]: Precision: 0.0071 Recall: 0.064 NDCG: 0.034 MRR: 0.0328
# ------------------------------------------------------
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Epoch: 75
# Evaluating:   0%|          | 0/182 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/182 [00:00<?, ?it/s]
# [Valid]: Precision: 0.0161 Recall: 0.0914 NDCG: 0.0557 MRR: 0.0659
# [Test]: Precision: 0.0071 Recall: 0.0641 NDCG: 0.0337 MRR: 0.0325
# ------------------------------------------------------
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# ------------------
# Exiting from training early
# ======================================================
# End. Best Epoch 060
# [Valid]: Precision: 0.0165 Recall: 0.0933 NDCG: 0.0566 MRR: 0.0666
# [Test]: Precision: 0.0073 Recall: 0.0655 NDCG: 0.0345 MRR: 0.0331
# End time:  2026-04-13 06:53:24
# Best model saved to  ./saved_models/amazon-books_lr0.0001_wd1e-05_bs512_ibs512_dims[1000, 1000]_emb12_x0_steps60_scale0.1_min1e-05_max0.02_sample0_reweightTrue_r1.pth

# %%
if __name__ == "__main__":
    # Make a Namespace class containing arguments for training
    args = Namespace(
        cuda = True, # Un-check this if there is no CUDA-supported device
        topN = "[20]", # Use Recall@20 only for validation
        dataset = "amazon-books", 
        tst_w_val = True, # Use validation with training to predict test
        lr = 1e-4, # Learning rate
        weight_decay = 1e-5, # Model control coefficient
        batch_size = 512, # Batch size when training
        epochs = 1000,
        dims = "[1000, 1000]", # Underlying Denoising MLP model
        emb_size = 12, # Timestep-embedding, necessary for Diffusion model
        steps = 60, # Denoising steps
        noise_scale = 0.1, 
        noise_min = 1e-5,
        noise_max = 0.02,
        sampling_steps = 0, # No sampling in inference
        loss_logging = False, # Turn off epoch loss/cost results, producing clean log
        log_name = "r2"
    )
    train_model(args)
# Out:
# args: Namespace(dataset='amazon-books', data_path='./datasets/', lr=0.0001, weight_decay=1e-05, batch_size=512, infer_batch_size=0, epochs=1000, topN='[20]', tst_w_val=True, cuda=True, gpu='0', save_path='./saved_models/', log_name='r2', round=1, loss_logging=False, time_type='cat', dims='[1000, 1000]', norm=False, emb_size=12, mean_type='x0', steps=60, noise_schedule='linear-var', noise_scale=0.1, noise_min=1e-05, noise_max=0.02, sampling_noise=False, sampling_steps=0, reweight=True)
# Starting time:  2026-04-13 07:05:09
# user num: 92993
# item num: 77884
# data ready.
# models ready.
# Number of all parameters: 157861040
# Start training...
# ======================================================
# Training:   0%|          | 0/1000 [00:00<?, ?it/s]
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Epoch: 5
# Evaluating:   0%|          | 0/182 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/182 [00:00<?, ?it/s]
# [Valid]: Precision: 0.0105 Recall: 0.0578 NDCG: 0.0351 MRR: 0.0429
# [Test]: Precision: 0.0047 Recall: 0.0413 NDCG: 0.0216 MRR: 0.0212
# ------------------------------------------------------
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Epoch: 10
# Evaluating:   0%|          | 0/182 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/182 [00:00<?, ?it/s]
# [Valid]: Precision: 0.0113 Recall: 0.0631 NDCG: 0.0385 MRR: 0.0462
# [Test]: Precision: 0.005 Recall: 0.0442 NDCG: 0.0235 MRR: 0.023
# ------------------------------------------------------
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Epoch: 15
# Evaluating:   0%|          | 0/182 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/182 [00:00<?, ?it/s]
# [Valid]: Precision: 0.0039 Recall: 0.0211 NDCG: 0.0138 MRR: 0.0182
# [Test]: Precision: 0.0016 Recall: 0.0144 NDCG: 0.0083 MRR: 0.0088
# ------------------------------------------------------
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Epoch: 20
# Evaluating:   0%|          | 0/182 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/182 [00:00<?, ?it/s]
# [Valid]: Precision: 0.006 Recall: 0.0336 NDCG: 0.0212 MRR: 0.0265
# [Test]: Precision: 0.0027 Recall: 0.024 NDCG: 0.0132 MRR: 0.0133
# ------------------------------------------------------
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Epoch: 25
# Evaluating:   0%|          | 0/182 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/182 [00:00<?, ?it/s]
# [Valid]: Precision: 0.0153 Recall: 0.0858 NDCG: 0.052 MRR: 0.0612
# [Test]: Precision: 0.0067 Recall: 0.06 NDCG: 0.0317 MRR: 0.0307
# ------------------------------------------------------
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Epoch: 30
# Evaluating:   0%|          | 0/182 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/182 [00:00<?, ?it/s]
# [Valid]: Precision: 0.0157 Recall: 0.0885 NDCG: 0.0533 MRR: 0.0626
# [Test]: Precision: 0.0069 Recall: 0.062 NDCG: 0.0326 MRR: 0.0313
# ------------------------------------------------------
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Epoch: 35
# Evaluating:   0%|          | 0/182 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/182 [00:00<?, ?it/s]
# [Valid]: Precision: 0.0153 Recall: 0.0862 NDCG: 0.0528 MRR: 0.0628
# [Test]: Precision: 0.0068 Recall: 0.0607 NDCG: 0.0321 MRR: 0.0312
# ------------------------------------------------------
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Epoch: 40
# Evaluating:   0%|          | 0/182 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/182 [00:00<?, ?it/s]
# [Valid]: Precision: 0.0153 Recall: 0.0867 NDCG: 0.0528 MRR: 0.0625
# [Test]: Precision: 0.0066 Recall: 0.06 NDCG: 0.0318 MRR: 0.0308
# ------------------------------------------------------
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Epoch: 45
# Evaluating:   0%|          | 0/182 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/182 [00:00<?, ?it/s]
# [Valid]: Precision: 0.016 Recall: 0.0903 NDCG: 0.0551 MRR: 0.0655
# [Test]: Precision: 0.007 Recall: 0.0633 NDCG: 0.0336 MRR: 0.0328
# ------------------------------------------------------
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Epoch: 50
# Evaluating:   0%|          | 0/182 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/182 [00:00<?, ?it/s]
# [Valid]: Precision: 0.0159 Recall: 0.0901 NDCG: 0.0545 MRR: 0.064
# [Test]: Precision: 0.007 Recall: 0.0632 NDCG: 0.0331 MRR: 0.0317
# ------------------------------------------------------
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Epoch: 55
# Evaluating:   0%|          | 0/182 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/182 [00:00<?, ?it/s]
# [Valid]: Precision: 0.0163 Recall: 0.0924 NDCG: 0.056 MRR: 0.066
# [Test]: Precision: 0.0072 Recall: 0.0649 NDCG: 0.0343 MRR: 0.0332
# ------------------------------------------------------
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Epoch: 60
# Evaluating:   0%|          | 0/182 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/182 [00:00<?, ?it/s]
# [Valid]: Precision: 0.0165 Recall: 0.0933 NDCG: 0.0566 MRR: 0.0666
# [Test]: Precision: 0.0073 Recall: 0.0655 NDCG: 0.0345 MRR: 0.0331
# ------------------------------------------------------
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Epoch: 65
# Evaluating:   0%|          | 0/182 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/182 [00:00<?, ?it/s]
# [Valid]: Precision: 0.016 Recall: 0.0908 NDCG: 0.055 MRR: 0.0648
# [Test]: Precision: 0.0071 Recall: 0.0636 NDCG: 0.0336 MRR: 0.0325
# ------------------------------------------------------
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Epoch: 70
# Evaluating:   0%|          | 0/182 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/182 [00:00<?, ?it/s]
# [Valid]: Precision: 0.0162 Recall: 0.0913 NDCG: 0.0557 MRR: 0.0659
# [Test]: Precision: 0.0071 Recall: 0.064 NDCG: 0.034 MRR: 0.0328
# ------------------------------------------------------
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Epoch: 75
# Evaluating:   0%|          | 0/182 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/182 [00:00<?, ?it/s]
# [Valid]: Precision: 0.0161 Recall: 0.0914 NDCG: 0.0557 MRR: 0.0659
# [Test]: Precision: 0.0071 Recall: 0.0641 NDCG: 0.0337 MRR: 0.0325
# ------------------------------------------------------
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# ------------------
# Exiting from training early
# ======================================================
# End. Best Epoch 060
# [Valid]: Precision: 0.0165 Recall: 0.0933 NDCG: 0.0566 MRR: 0.0666
# [Test]: Precision: 0.0073 Recall: 0.0655 NDCG: 0.0345 MRR: 0.0331
# End time:  2026-04-13 10:23:51
# Best model saved to  ./saved_models/amazon-books_lr0.0001_wd1e-05_bs512_ibs512_dims[1000, 1000]_emb12_x0_steps60_scale0.1_min1e-05_max0.02_sample0_reweightTrue_r2.pth

# %%
if __name__ == "__main__":
    # Make a Namespace class containing arguments for training
    args = Namespace(
        cuda = True, # Un-check this if there is no CUDA-supported device
        topN = "[20]", # Use Recall@20 only for validation
        dataset = "amazon-books", 
        tst_w_val = True, # Use validation with training to predict test
        lr = 1e-4, # Learning rate
        weight_decay = 1e-5, # Model control coefficient
        batch_size = 512, # Batch size when training
        epochs = 1000,
        dims = "[1000, 1000]", # Underlying Denoising MLP model
        emb_size = 12, # Timestep-embedding, necessary for Diffusion model
        steps = 60, # Denoising steps
        noise_scale = 0.1, 
        noise_min = 1e-5,
        noise_max = 0.02,
        sampling_steps = 0, # No sampling in inference
        loss_logging = False, # Turn off epoch loss/cost results, producing clean log
        log_name = "r3"
    )
    train_model(args)
# Out:
# args: Namespace(dataset='amazon-books', data_path='./datasets/', lr=0.0001, weight_decay=1e-05, batch_size=512, infer_batch_size=0, epochs=1000, topN='[20]', tst_w_val=True, cuda=True, gpu='0', save_path='./saved_models/', log_name='r3', round=1, loss_logging=False, time_type='cat', dims='[1000, 1000]', norm=False, emb_size=12, mean_type='x0', steps=60, noise_schedule='linear-var', noise_scale=0.1, noise_min=1e-05, noise_max=0.02, sampling_noise=False, sampling_steps=0, reweight=True)
# Starting time:  2026-04-13 13:12:03
# user num: 92993
# item num: 77884
# data ready.
# models ready.
# Number of all parameters: 157861040
# Start training...
# ======================================================
# Training:   0%|          | 0/1000 [00:00<?, ?it/s]
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Epoch: 5
# Evaluating:   0%|          | 0/182 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/182 [00:00<?, ?it/s]
# [Valid]: Precision: 0.0105 Recall: 0.0578 NDCG: 0.0351 MRR: 0.0429
# [Test]: Precision: 0.0047 Recall: 0.0413 NDCG: 0.0216 MRR: 0.0212
# ------------------------------------------------------
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Epoch: 10
# Evaluating:   0%|          | 0/182 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/182 [00:00<?, ?it/s]
# [Valid]: Precision: 0.0113 Recall: 0.0631 NDCG: 0.0385 MRR: 0.0462
# [Test]: Precision: 0.005 Recall: 0.0442 NDCG: 0.0235 MRR: 0.023
# ------------------------------------------------------
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Epoch: 15
# Evaluating:   0%|          | 0/182 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/182 [00:00<?, ?it/s]
# [Valid]: Precision: 0.0039 Recall: 0.0211 NDCG: 0.0138 MRR: 0.0182
# [Test]: Precision: 0.0016 Recall: 0.0144 NDCG: 0.0083 MRR: 0.0088
# ------------------------------------------------------
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Epoch: 20
# Evaluating:   0%|          | 0/182 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/182 [00:00<?, ?it/s]
# [Valid]: Precision: 0.006 Recall: 0.0336 NDCG: 0.0212 MRR: 0.0265
# [Test]: Precision: 0.0027 Recall: 0.024 NDCG: 0.0132 MRR: 0.0133
# ------------------------------------------------------
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Epoch: 25
# Evaluating:   0%|          | 0/182 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/182 [00:00<?, ?it/s]
# [Valid]: Precision: 0.0153 Recall: 0.0858 NDCG: 0.052 MRR: 0.0612
# [Test]: Precision: 0.0067 Recall: 0.06 NDCG: 0.0317 MRR: 0.0307
# ------------------------------------------------------
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Epoch: 30
# Evaluating:   0%|          | 0/182 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/182 [00:00<?, ?it/s]
# [Valid]: Precision: 0.0157 Recall: 0.0885 NDCG: 0.0533 MRR: 0.0626
# [Test]: Precision: 0.0069 Recall: 0.062 NDCG: 0.0326 MRR: 0.0313
# ------------------------------------------------------
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Epoch: 35
# Evaluating:   0%|          | 0/182 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/182 [00:00<?, ?it/s]
# [Valid]: Precision: 0.0153 Recall: 0.0862 NDCG: 0.0528 MRR: 0.0628
# [Test]: Precision: 0.0068 Recall: 0.0607 NDCG: 0.0321 MRR: 0.0312
# ------------------------------------------------------
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Epoch: 40
# Evaluating:   0%|          | 0/182 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/182 [00:00<?, ?it/s]
# [Valid]: Precision: 0.0153 Recall: 0.0867 NDCG: 0.0528 MRR: 0.0625
# [Test]: Precision: 0.0066 Recall: 0.06 NDCG: 0.0318 MRR: 0.0308
# ------------------------------------------------------
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Epoch: 45
# Evaluating:   0%|          | 0/182 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/182 [00:00<?, ?it/s]
# [Valid]: Precision: 0.016 Recall: 0.0903 NDCG: 0.0551 MRR: 0.0655
# [Test]: Precision: 0.007 Recall: 0.0633 NDCG: 0.0336 MRR: 0.0328
# ------------------------------------------------------
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Epoch: 50
# Evaluating:   0%|          | 0/182 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/182 [00:00<?, ?it/s]
# [Valid]: Precision: 0.0159 Recall: 0.0901 NDCG: 0.0545 MRR: 0.064
# [Test]: Precision: 0.007 Recall: 0.0632 NDCG: 0.0331 MRR: 0.0317
# ------------------------------------------------------
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Epoch: 55
# Evaluating:   0%|          | 0/182 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/182 [00:00<?, ?it/s]
# [Valid]: Precision: 0.0163 Recall: 0.0924 NDCG: 0.056 MRR: 0.066
# [Test]: Precision: 0.0072 Recall: 0.0649 NDCG: 0.0343 MRR: 0.0332
# ------------------------------------------------------
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Epoch: 60
# Evaluating:   0%|          | 0/182 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/182 [00:00<?, ?it/s]
# [Valid]: Precision: 0.0165 Recall: 0.0933 NDCG: 0.0566 MRR: 0.0666
# [Test]: Precision: 0.0073 Recall: 0.0655 NDCG: 0.0345 MRR: 0.0331
# ------------------------------------------------------
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Epoch: 65
# Evaluating:   0%|          | 0/182 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/182 [00:00<?, ?it/s]
# [Valid]: Precision: 0.016 Recall: 0.0908 NDCG: 0.055 MRR: 0.0648
# [Test]: Precision: 0.0071 Recall: 0.0636 NDCG: 0.0336 MRR: 0.0325
# ------------------------------------------------------
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Epoch: 70
# Evaluating:   0%|          | 0/182 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/182 [00:00<?, ?it/s]
# [Valid]: Precision: 0.0162 Recall: 0.0913 NDCG: 0.0557 MRR: 0.0659
# [Test]: Precision: 0.0071 Recall: 0.064 NDCG: 0.034 MRR: 0.0328
# ------------------------------------------------------
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Epoch: 75
# Evaluating:   0%|          | 0/182 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/182 [00:00<?, ?it/s]
# [Valid]: Precision: 0.0161 Recall: 0.0914 NDCG: 0.0557 MRR: 0.0659
# [Test]: Precision: 0.0071 Recall: 0.0641 NDCG: 0.0337 MRR: 0.0325
# ------------------------------------------------------
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# Batches:   0%|          | 0/182 [00:00<?, ?it/s]
# ------------------
# Exiting from training early
# ======================================================
# End. Best Epoch 060
# [Valid]: Precision: 0.0165 Recall: 0.0933 NDCG: 0.0566 MRR: 0.0666
# [Test]: Precision: 0.0073 Recall: 0.0655 NDCG: 0.0345 MRR: 0.0331
# End time:  2026-04-13 16:35:57
# Best model saved to  ./saved_models/amazon-books_lr0.0001_wd1e-05_bs512_ibs512_dims[1000, 1000]_emb12_x0_steps60_scale0.1_min1e-05_max0.02_sample0_reweightTrue_r3.pth
