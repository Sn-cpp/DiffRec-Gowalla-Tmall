# %%
import os
from argparse import Namespace

# %%
os.environ["USE_TQDM_NOTEBOOK"] = "1"

# %%
from main import train_model
from inference import infer_model

# %%
if __name__ == "__main__":
    # Make a Namespace class containing arguments for training
    args = Namespace(
        cuda = True, # Un-check this if there is no CUDA-supported device
        topN = "[20]", # Use Recall@20 only for validation
        dataset = "yelp", 
        tst_w_val = True, # Use validation with training to predict test
        lr = 1e-4, # Learning rate
        weight_decay = 1e-5, # Model control coefficient
        batch_size = 512, # Batch size when training
        epochs = 1000,
        dims = "[1000, 1000]", # Underlying Denoising MLP model
        emb_size = 12, # Timestep-embedding, necessary for Diffusion model
        steps = 60, # Denoising steps
        noise_scale = 0.1, 
        noise_min = 1e-5,
        noise_max = 0.02,
        sampling_steps = 0, # No sampling in inference
        loss_logging = False, # Turn off epoch loss/cost results, producing clean log
        log_name = "r1"
    )
    train_model(args)
# Out:
# args: Namespace(dataset='yelp', data_path='./datasets/', lr=0.0001, weight_decay=1e-05, batch_size=512, infer_batch_size=0, epochs=1000, topN='[20]', tst_w_val=True, cuda=True, gpu='0', save_path='./saved_models/', log_name='r1', round=1, loss_logging=False, time_type='cat', dims='[1000, 1000]', norm=False, emb_size=12, mean_type='x0', steps=60, noise_schedule='linear-var', noise_scale=0.1, noise_min=1e-05, noise_max=0.02, sampling_noise=False, sampling_steps=0, reweight=True)
# Starting time:  2026-04-13 22:09:31
# user num: 93537
# item num: 53347
# data ready.
# models ready.
# Number of all parameters: 108762503
# Start training...
# ======================================================
# Training:   0%|          | 0/1000 [00:00<?, ?it/s]
# Batches:   0%|          | 0/183 [00:00<?, ?it/s]
# Batches:   0%|          | 0/183 [00:00<?, ?it/s]
# Batches:   0%|          | 0/183 [00:00<?, ?it/s]
# Batches:   0%|          | 0/183 [00:00<?, ?it/s]
# Batches:   0%|          | 0/183 [00:00<?, ?it/s]
# Epoch: 5
# Evaluating:   0%|          | 0/183 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/183 [00:00<?, ?it/s]
# [Valid]: Precision: 0.0156 Recall: 0.0672 NDCG: 0.0423 MRR: 0.0641
# [Test]: Precision: 0.0083 Recall: 0.0573 NDCG: 0.0307 MRR: 0.0364
# ------------------------------------------------------
# Batches:   0%|          | 0/183 [00:00<?, ?it/s]
# Batches:   0%|          | 0/183 [00:00<?, ?it/s]
# Batches:   0%|          | 0/183 [00:00<?, ?it/s]
# Batches:   0%|          | 0/183 [00:00<?, ?it/s]
# Batches:   0%|          | 0/183 [00:00<?, ?it/s]
# Epoch: 10
# Evaluating:   0%|          | 0/183 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/183 [00:00<?, ?it/s]
# [Valid]: Precision: 0.0167 Recall: 0.0715 NDCG: 0.0451 MRR: 0.0684
# [Test]: Precision: 0.0088 Recall: 0.0609 NDCG: 0.033 MRR: 0.0394
# ------------------------------------------------------
# Batches:   0%|          | 0/183 [00:00<?, ?it/s]
# Batches:   0%|          | 0/183 [00:00<?, ?it/s]
# Batches:   0%|          | 0/183 [00:00<?, ?it/s]
# Batches:   0%|          | 0/183 [00:00<?, ?it/s]
# Batches:   0%|          | 0/183 [00:00<?, ?it/s]
# Epoch: 15
# Evaluating:   0%|          | 0/183 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/183 [00:00<?, ?it/s]
# [Valid]: Precision: 0.0161 Recall: 0.0685 NDCG: 0.0439 MRR: 0.0674
# [Test]: Precision: 0.0086 Recall: 0.0591 NDCG: 0.032 MRR: 0.0383
# ------------------------------------------------------
# Batches:   0%|          | 0/183 [00:00<?, ?it/s]
# Batches:   0%|          | 0/183 [00:00<?, ?it/s]
# Batches:   0%|          | 0/183 [00:00<?, ?it/s]
# Batches:   0%|          | 0/183 [00:00<?, ?it/s]
# Batches:   0%|          | 0/183 [00:00<?, ?it/s]
# Epoch: 20
# Evaluating:   0%|          | 0/183 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/183 [00:00<?, ?it/s]
# [Valid]: Precision: 0.0171 Recall: 0.0728 NDCG: 0.0467 MRR: 0.0718
# [Test]: Precision: 0.009 Recall: 0.0621 NDCG: 0.0342 MRR: 0.0414
# ------------------------------------------------------
# Batches:   0%|          | 0/183 [00:00<?, ?it/s]
# Batches:   0%|          | 0/183 [00:00<?, ?it/s]
# Batches:   0%|          | 0/183 [00:00<?, ?it/s]
# Batches:   0%|          | 0/183 [00:00<?, ?it/s]
# Batches:   0%|          | 0/183 [00:00<?, ?it/s]
# Epoch: 25
# Evaluating:   0%|          | 0/183 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/183 [00:00<?, ?it/s]
# [Valid]: Precision: 0.0058 Recall: 0.022 NDCG: 0.0145 MRR: 0.0238
# [Test]: Precision: 0.0032 Recall: 0.0208 NDCG: 0.0115 MRR: 0.0144
# ------------------------------------------------------
# Batches:   0%|          | 0/183 [00:00<?, ?it/s]
# Batches:   0%|          | 0/183 [00:00<?, ?it/s]
# Batches:   0%|          | 0/183 [00:00<?, ?it/s]
# Batches:   0%|          | 0/183 [00:00<?, ?it/s]
# Batches:   0%|          | 0/183 [00:00<?, ?it/s]
# Epoch: 30
# Evaluating:   0%|          | 0/183 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/183 [00:00<?, ?it/s]
# [Valid]: Precision: 0.0167 Recall: 0.0717 NDCG: 0.0456 MRR: 0.0696
# [Test]: Precision: 0.0089 Recall: 0.0615 NDCG: 0.0335 MRR: 0.0403
# ------------------------------------------------------
# Batches:   0%|          | 0/183 [00:00<?, ?it/s]
# Batches:   0%|          | 0/183 [00:00<?, ?it/s]
# Batches:   0%|          | 0/183 [00:00<?, ?it/s]
# Batches:   0%|          | 0/183 [00:00<?, ?it/s]
# Batches:   0%|          | 0/183 [00:00<?, ?it/s]
# Epoch: 35
# Evaluating:   0%|          | 0/183 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/183 [00:00<?, ?it/s]
# [Valid]: Precision: 0.0165 Recall: 0.0692 NDCG: 0.0446 MRR: 0.0694
# [Test]: Precision: 0.0088 Recall: 0.0601 NDCG: 0.0331 MRR: 0.0404
# ------------------------------------------------------
# Batches:   0%|          | 0/183 [00:00<?, ?it/s]
# Batches:   0%|          | 0/183 [00:00<?, ?it/s]
# Batches:   0%|          | 0/183 [00:00<?, ?it/s]
# Batches:   0%|          | 0/183 [00:00<?, ?it/s]
# ------------------
# Exiting from training early
# ======================================================
# End. Best Epoch 020
# [Valid]: Precision: 0.0171 Recall: 0.0728 NDCG: 0.0467 MRR: 0.0718
# [Test]: Precision: 0.009 Recall: 0.0621 NDCG: 0.0342 MRR: 0.0414
# End time:  2026-04-13 23:27:08
# Best model saved to  ./saved_models/yelp_lr0.0001_wd1e-05_bs512_ibs512_dims[1000, 1000]_emb12_x0_steps60_scale0.1_min1e-05_max0.02_sample0_reweightTrue_r1.pth

# %%
if __name__ == "__main__":
    # Make a Namespace class containing arguments for training
    args = Namespace(
        cuda = True, # Un-check this if there is no CUDA-supported device
        topN = "[20]", # Use Recall@20 only for validation
        dataset = "yelp", 
        tst_w_val = True, # Use validation with training to predict test
        lr = 1e-4, # Learning rate
        weight_decay = 1e-5, # Model control coefficient
        batch_size = 512, # Batch size when training
        epochs = 1000,
        dims = "[1000, 1000]", # Underlying Denoising MLP model
        emb_size = 12, # Timestep-embedding, necessary for Diffusion model
        steps = 60, # Denoising steps
        noise_scale = 0.1, 
        noise_min = 1e-5,
        noise_max = 0.02,
        sampling_steps = 0, # No sampling in inference
        loss_logging = False, # Turn off epoch loss/cost results, producing clean log
        log_name = "r2"
    )
    train_model(args)
# Out:
# args: Namespace(dataset='yelp', data_path='./datasets/', lr=0.0001, weight_decay=1e-05, batch_size=512, infer_batch_size=0, epochs=1000, topN='[20]', tst_w_val=True, cuda=True, gpu='0', save_path='./saved_models/', log_name='r2', round=1, loss_logging=False, time_type='cat', dims='[1000, 1000]', norm=False, emb_size=12, mean_type='x0', steps=60, noise_schedule='linear-var', noise_scale=0.1, noise_min=1e-05, noise_max=0.02, sampling_noise=False, sampling_steps=0, reweight=True)
# Starting time:  2026-04-14 00:07:05
# user num: 93537
# item num: 53347
# data ready.
# models ready.
# Number of all parameters: 108762503
# Start training...
# ======================================================
# Training:   0%|          | 0/1000 [00:00<?, ?it/s]
# Batches:   0%|          | 0/183 [00:00<?, ?it/s]
# Batches:   0%|          | 0/183 [00:00<?, ?it/s]
# Batches:   0%|          | 0/183 [00:00<?, ?it/s]
# Batches:   0%|          | 0/183 [00:00<?, ?it/s]
# Batches:   0%|          | 0/183 [00:00<?, ?it/s]
# Epoch: 5
# Evaluating:   0%|          | 0/183 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/183 [00:00<?, ?it/s]
# [Valid]: Precision: 0.0156 Recall: 0.0672 NDCG: 0.0423 MRR: 0.0641
# [Test]: Precision: 0.0083 Recall: 0.0573 NDCG: 0.0307 MRR: 0.0364
# ------------------------------------------------------
# Batches:   0%|          | 0/183 [00:00<?, ?it/s]
# Batches:   0%|          | 0/183 [00:00<?, ?it/s]
# Batches:   0%|          | 0/183 [00:00<?, ?it/s]
# Batches:   0%|          | 0/183 [00:00<?, ?it/s]
# Batches:   0%|          | 0/183 [00:00<?, ?it/s]
# Epoch: 10
# Evaluating:   0%|          | 0/183 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/183 [00:00<?, ?it/s]
# [Valid]: Precision: 0.0167 Recall: 0.0715 NDCG: 0.0451 MRR: 0.0684
# [Test]: Precision: 0.0088 Recall: 0.0609 NDCG: 0.033 MRR: 0.0394
# ------------------------------------------------------
# Batches:   0%|          | 0/183 [00:00<?, ?it/s]
# Batches:   0%|          | 0/183 [00:00<?, ?it/s]
# Batches:   0%|          | 0/183 [00:00<?, ?it/s]
# Batches:   0%|          | 0/183 [00:00<?, ?it/s]
# Batches:   0%|          | 0/183 [00:00<?, ?it/s]
# Epoch: 15
# Evaluating:   0%|          | 0/183 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/183 [00:00<?, ?it/s]
# [Valid]: Precision: 0.0161 Recall: 0.0685 NDCG: 0.0439 MRR: 0.0674
# [Test]: Precision: 0.0086 Recall: 0.0591 NDCG: 0.032 MRR: 0.0383
# ------------------------------------------------------
# Batches:   0%|          | 0/183 [00:00<?, ?it/s]
# Batches:   0%|          | 0/183 [00:00<?, ?it/s]
# Batches:   0%|          | 0/183 [00:00<?, ?it/s]
# Batches:   0%|          | 0/183 [00:00<?, ?it/s]
# Batches:   0%|          | 0/183 [00:00<?, ?it/s]
# Epoch: 20
# Evaluating:   0%|          | 0/183 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/183 [00:00<?, ?it/s]
# [Valid]: Precision: 0.0171 Recall: 0.0728 NDCG: 0.0467 MRR: 0.0718
# [Test]: Precision: 0.009 Recall: 0.0621 NDCG: 0.0342 MRR: 0.0414
# ------------------------------------------------------
# Batches:   0%|          | 0/183 [00:00<?, ?it/s]
# Batches:   0%|          | 0/183 [00:00<?, ?it/s]
# Batches:   0%|          | 0/183 [00:00<?, ?it/s]
# Batches:   0%|          | 0/183 [00:00<?, ?it/s]
# Batches:   0%|          | 0/183 [00:00<?, ?it/s]
# Epoch: 25
# Evaluating:   0%|          | 0/183 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/183 [00:00<?, ?it/s]
# [Valid]: Precision: 0.0058 Recall: 0.022 NDCG: 0.0145 MRR: 0.0238
# [Test]: Precision: 0.0032 Recall: 0.0208 NDCG: 0.0115 MRR: 0.0144
# ------------------------------------------------------
# Batches:   0%|          | 0/183 [00:00<?, ?it/s]
# Batches:   0%|          | 0/183 [00:00<?, ?it/s]
# Batches:   0%|          | 0/183 [00:00<?, ?it/s]
# Batches:   0%|          | 0/183 [00:00<?, ?it/s]
# Batches:   0%|          | 0/183 [00:00<?, ?it/s]
# Epoch: 30
# Evaluating:   0%|          | 0/183 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/183 [00:00<?, ?it/s]
# [Valid]: Precision: 0.0167 Recall: 0.0717 NDCG: 0.0456 MRR: 0.0696
# [Test]: Precision: 0.0089 Recall: 0.0615 NDCG: 0.0335 MRR: 0.0403
# ------------------------------------------------------
# Batches:   0%|          | 0/183 [00:00<?, ?it/s]
# Batches:   0%|          | 0/183 [00:00<?, ?it/s]
# Batches:   0%|          | 0/183 [00:00<?, ?it/s]
# Batches:   0%|          | 0/183 [00:00<?, ?it/s]
# Batches:   0%|          | 0/183 [00:00<?, ?it/s]
# Epoch: 35
# Evaluating:   0%|          | 0/183 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/183 [00:00<?, ?it/s]
# [Valid]: Precision: 0.0165 Recall: 0.0692 NDCG: 0.0446 MRR: 0.0694
# [Test]: Precision: 0.0088 Recall: 0.0601 NDCG: 0.0331 MRR: 0.0404
# ------------------------------------------------------
# Batches:   0%|          | 0/183 [00:00<?, ?it/s]
# Batches:   0%|          | 0/183 [00:00<?, ?it/s]
# Batches:   0%|          | 0/183 [00:00<?, ?it/s]
# Batches:   0%|          | 0/183 [00:00<?, ?it/s]
# ------------------
# Exiting from training early
# ======================================================
# End. Best Epoch 020
# [Valid]: Precision: 0.0171 Recall: 0.0728 NDCG: 0.0467 MRR: 0.0718
# [Test]: Precision: 0.009 Recall: 0.0621 NDCG: 0.0342 MRR: 0.0414
# End time:  2026-04-14 01:26:23
# Best model saved to  ./saved_models/yelp_lr0.0001_wd1e-05_bs512_ibs512_dims[1000, 1000]_emb12_x0_steps60_scale0.1_min1e-05_max0.02_sample0_reweightTrue_r2.pth

# %%
if __name__ == "__main__":
    # Make a Namespace class containing arguments for training
    args = Namespace(
        cuda = True, # Un-check this if there is no CUDA-supported device
        topN = "[20]", # Use Recall@20 only for validation
        dataset = "yelp", 
        tst_w_val = True, # Use validation with training to predict test
        lr = 1e-4, # Learning rate
        weight_decay = 1e-5, # Model control coefficient
        batch_size = 512, # Batch size when training
        epochs = 1000,
        dims = "[1000, 1000]", # Underlying Denoising MLP model
        emb_size = 12, # Timestep-embedding, necessary for Diffusion model
        steps = 60, # Denoising steps
        noise_scale = 0.1, 
        noise_min = 1e-5,
        noise_max = 0.02,
        sampling_steps = 0, # No sampling in inference
        loss_logging = False, # Turn off epoch loss/cost results, producing clean log
        log_name = "r3"
    )
    train_model(args)
# Out:
# args: Namespace(dataset='yelp', data_path='./datasets/', lr=0.0001, weight_decay=1e-05, batch_size=512, infer_batch_size=0, epochs=1000, topN='[20]', tst_w_val=True, cuda=True, gpu='0', save_path='./saved_models/', log_name='r3', round=1, loss_logging=False, time_type='cat', dims='[1000, 1000]', norm=False, emb_size=12, mean_type='x0', steps=60, noise_schedule='linear-var', noise_scale=0.1, noise_min=1e-05, noise_max=0.02, sampling_noise=False, sampling_steps=0, reweight=True)
# Starting time:  2026-04-14 01:26:23
# user num: 93537
# item num: 53347
# data ready.
# models ready.
# Number of all parameters: 108762503
# Start training...
# ======================================================
# Training:   0%|          | 0/1000 [00:00<?, ?it/s]
# Batches:   0%|          | 0/183 [00:00<?, ?it/s]
# Batches:   0%|          | 0/183 [00:00<?, ?it/s]
# Batches:   0%|          | 0/183 [00:00<?, ?it/s]
# Batches:   0%|          | 0/183 [00:00<?, ?it/s]
# Batches:   0%|          | 0/183 [00:00<?, ?it/s]
# Epoch: 5
# Evaluating:   0%|          | 0/183 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/183 [00:00<?, ?it/s]
# [Valid]: Precision: 0.0156 Recall: 0.0672 NDCG: 0.0423 MRR: 0.0641
# [Test]: Precision: 0.0083 Recall: 0.0573 NDCG: 0.0307 MRR: 0.0364
# ------------------------------------------------------
# Batches:   0%|          | 0/183 [00:00<?, ?it/s]
# Batches:   0%|          | 0/183 [00:00<?, ?it/s]
# Batches:   0%|          | 0/183 [00:00<?, ?it/s]
# Batches:   0%|          | 0/183 [00:00<?, ?it/s]
# Batches:   0%|          | 0/183 [00:00<?, ?it/s]
# Epoch: 10
# Evaluating:   0%|          | 0/183 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/183 [00:00<?, ?it/s]
# [Valid]: Precision: 0.0167 Recall: 0.0715 NDCG: 0.0451 MRR: 0.0684
# [Test]: Precision: 0.0088 Recall: 0.0609 NDCG: 0.033 MRR: 0.0394
# ------------------------------------------------------
# Batches:   0%|          | 0/183 [00:00<?, ?it/s]
# Batches:   0%|          | 0/183 [00:00<?, ?it/s]
# Batches:   0%|          | 0/183 [00:00<?, ?it/s]
# Batches:   0%|          | 0/183 [00:00<?, ?it/s]
# Batches:   0%|          | 0/183 [00:00<?, ?it/s]
# Epoch: 15
# Evaluating:   0%|          | 0/183 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/183 [00:00<?, ?it/s]
# [Valid]: Precision: 0.0161 Recall: 0.0685 NDCG: 0.0439 MRR: 0.0674
# [Test]: Precision: 0.0086 Recall: 0.0591 NDCG: 0.032 MRR: 0.0383
# ------------------------------------------------------
# Batches:   0%|          | 0/183 [00:00<?, ?it/s]
# Batches:   0%|          | 0/183 [00:00<?, ?it/s]
# Batches:   0%|          | 0/183 [00:00<?, ?it/s]
# Batches:   0%|          | 0/183 [00:00<?, ?it/s]
# Batches:   0%|          | 0/183 [00:00<?, ?it/s]
# Epoch: 20
# Evaluating:   0%|          | 0/183 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/183 [00:00<?, ?it/s]
# [Valid]: Precision: 0.0171 Recall: 0.0728 NDCG: 0.0467 MRR: 0.0718
# [Test]: Precision: 0.009 Recall: 0.0621 NDCG: 0.0342 MRR: 0.0414
# ------------------------------------------------------
# Batches:   0%|          | 0/183 [00:00<?, ?it/s]
# Batches:   0%|          | 0/183 [00:00<?, ?it/s]
# Batches:   0%|          | 0/183 [00:00<?, ?it/s]
# Batches:   0%|          | 0/183 [00:00<?, ?it/s]
# Batches:   0%|          | 0/183 [00:00<?, ?it/s]
# Epoch: 25
# Evaluating:   0%|          | 0/183 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/183 [00:00<?, ?it/s]
# [Valid]: Precision: 0.0058 Recall: 0.022 NDCG: 0.0145 MRR: 0.0238
# [Test]: Precision: 0.0032 Recall: 0.0208 NDCG: 0.0115 MRR: 0.0144
# ------------------------------------------------------
# Batches:   0%|          | 0/183 [00:00<?, ?it/s]
# Batches:   0%|          | 0/183 [00:00<?, ?it/s]
# Batches:   0%|          | 0/183 [00:00<?, ?it/s]
# Batches:   0%|          | 0/183 [00:00<?, ?it/s]
# Batches:   0%|          | 0/183 [00:00<?, ?it/s]
# Epoch: 30
# Evaluating:   0%|          | 0/183 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/183 [00:00<?, ?it/s]
# [Valid]: Precision: 0.0167 Recall: 0.0717 NDCG: 0.0456 MRR: 0.0696
# [Test]: Precision: 0.0089 Recall: 0.0615 NDCG: 0.0335 MRR: 0.0403
# ------------------------------------------------------
# Batches:   0%|          | 0/183 [00:00<?, ?it/s]
# Batches:   0%|          | 0/183 [00:00<?, ?it/s]
# Batches:   0%|          | 0/183 [00:00<?, ?it/s]
# Batches:   0%|          | 0/183 [00:00<?, ?it/s]
# Batches:   0%|          | 0/183 [00:00<?, ?it/s]
# Epoch: 35
# Evaluating:   0%|          | 0/183 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/183 [00:00<?, ?it/s]
# [Valid]: Precision: 0.0165 Recall: 0.0692 NDCG: 0.0446 MRR: 0.0694
# [Test]: Precision: 0.0088 Recall: 0.0601 NDCG: 0.0331 MRR: 0.0404
# ------------------------------------------------------
# Batches:   0%|          | 0/183 [00:00<?, ?it/s]
# Batches:   0%|          | 0/183 [00:00<?, ?it/s]
# Batches:   0%|          | 0/183 [00:00<?, ?it/s]
# Batches:   0%|          | 0/183 [00:00<?, ?it/s]
# ------------------
# Exiting from training early
# ======================================================
# End. Best Epoch 020
# [Valid]: Precision: 0.0171 Recall: 0.0728 NDCG: 0.0467 MRR: 0.0718
# [Test]: Precision: 0.009 Recall: 0.0621 NDCG: 0.0342 MRR: 0.0414
# End time:  2026-04-14 02:44:51
# Best model saved to  ./saved_models/yelp_lr0.0001_wd1e-05_bs512_ibs512_dims[1000, 1000]_emb12_x0_steps60_scale0.1_min1e-05_max0.02_sample0_reweightTrue_r3.pth
