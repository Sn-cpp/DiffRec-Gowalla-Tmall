# %%
import os
from argparse import Namespace

# %%
os.environ["USE_TQDM_NOTEBOOK"] = "1"

# %%
from main import train_model
from inference import infer_model

# %%
if __name__ == "__main__":
    # Make a Namespace class containing arguments for training
    args = Namespace(
        cuda = True, # Un-check this if there is no CUDA-supported device
        topN = "[20]", # Use Recall@20 only for validation
        dataset = "steam", 
        tst_w_val = True, # Use validation with training to predict test
        lr = 1e-4, # Learning rate
        weight_decay = 1e-5, # Model control coefficient
        batch_size = 512, # Batch size when training
        epochs = 1000,
        dims = "[1000, 1000]", # Underlying Denoising MLP model
        emb_size = 12, # Timestep-embedding, necessary for Diffusion model
        steps = 60, # Denoising steps
        noise_scale = 0.1, 
        noise_min = 1e-5,
        noise_max = 0.02,
        sampling_steps = 0, # No sampling in inference
        loss_logging = False, # Turn off epoch loss/cost results, producing clean log
        log_name = "r1"
    )
    train_model(args)
# Out:
# args: Namespace(dataset='steam', data_path='./datasets/', lr=0.0001, weight_decay=1e-05, batch_size=512, infer_batch_size=0, epochs=1000, topN='[20]', tst_w_val=True, cuda=True, gpu='0', save_path='./saved_models/', log_name='r1', round=1, loss_logging=False, time_type='cat', dims='[1000, 1000]', norm=False, emb_size=12, mean_type='x0', steps=60, noise_schedule='linear-var', noise_scale=0.1, noise_min=1e-05, noise_max=0.02, sampling_noise=False, sampling_steps=0, reweight=True)
# Starting time:  2026-04-16 18:52:34
# user num: 36321
# item num: 1980
# data ready.
# models ready.
# Number of all parameters: 5977136
# Start training...
# ======================================================
# Training:   0%|          | 0/1000 [00:00<?, ?it/s]
# Batches:   0%|          | 0/71 [00:00<?, ?it/s]
# Batches:   0%|          | 0/71 [00:00<?, ?it/s]
# Batches:   0%|          | 0/71 [00:00<?, ?it/s]
# Batches:   0%|          | 0/71 [00:00<?, ?it/s]
# Batches:   0%|          | 0/71 [00:00<?, ?it/s]
# Epoch: 5
# Evaluating:   0%|          | 0/71 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/71 [00:00<?, ?it/s]
# [Valid]: Precision: 0.037 Recall: 0.1279 NDCG: 0.0842 MRR: 0.1269
# [Test]: Precision: 0.0162 Recall: 0.1255 NDCG: 0.0631 MRR: 0.0645
# ------------------------------------------------------
# Batches:   0%|          | 0/71 [00:00<?, ?it/s]
# Batches:   0%|          | 0/71 [00:00<?, ?it/s]
# Batches:   0%|          | 0/71 [00:00<?, ?it/s]
# Batches:   0%|          | 0/71 [00:00<?, ?it/s]
# Batches:   0%|          | 0/71 [00:00<?, ?it/s]
# Epoch: 10
# Evaluating:   0%|          | 0/71 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/71 [00:00<?, ?it/s]
# [Valid]: Precision: 0.0411 Recall: 0.1419 NDCG: 0.0941 MRR: 0.1403
# [Test]: Precision: 0.0182 Recall: 0.1406 NDCG: 0.0715 MRR: 0.0736
# ------------------------------------------------------
# Batches:   0%|          | 0/71 [00:00<?, ?it/s]
# Batches:   0%|          | 0/71 [00:00<?, ?it/s]
# Batches:   0%|          | 0/71 [00:00<?, ?it/s]
# Batches:   0%|          | 0/71 [00:00<?, ?it/s]
# Batches:   0%|          | 0/71 [00:00<?, ?it/s]
# Epoch: 15
# Evaluating:   0%|          | 0/71 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/71 [00:00<?, ?it/s]
# [Valid]: Precision: 0.0419 Recall: 0.1444 NDCG: 0.0961 MRR: 0.1435
# [Test]: Precision: 0.0189 Recall: 0.1463 NDCG: 0.0742 MRR: 0.0755
# ------------------------------------------------------
# Batches:   0%|          | 0/71 [00:00<?, ?it/s]
# Batches:   0%|          | 0/71 [00:00<?, ?it/s]
# Batches:   0%|          | 0/71 [00:00<?, ?it/s]
# Batches:   0%|          | 0/71 [00:00<?, ?it/s]
# Batches:   0%|          | 0/71 [00:00<?, ?it/s]
# Epoch: 20
# Evaluating:   0%|          | 0/71 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/71 [00:00<?, ?it/s]
# [Valid]: Precision: 0.0422 Recall: 0.1461 NDCG: 0.0975 MRR: 0.1464
# [Test]: Precision: 0.0187 Recall: 0.1459 NDCG: 0.0743 MRR: 0.0762
# ------------------------------------------------------
# Batches:   0%|          | 0/71 [00:00<?, ?it/s]
# Batches:   0%|          | 0/71 [00:00<?, ?it/s]
# Batches:   0%|          | 0/71 [00:00<?, ?it/s]
# Batches:   0%|          | 0/71 [00:00<?, ?it/s]
# Batches:   0%|          | 0/71 [00:00<?, ?it/s]
# Epoch: 25
# Evaluating:   0%|          | 0/71 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/71 [00:00<?, ?it/s]
# [Valid]: Precision: 0.043 Recall: 0.1483 NDCG: 0.0989 MRR: 0.1477
# [Test]: Precision: 0.0191 Recall: 0.148 NDCG: 0.0753 MRR: 0.0771
# ------------------------------------------------------
# Batches:   0%|          | 0/71 [00:00<?, ?it/s]
# Batches:   0%|          | 0/71 [00:00<?, ?it/s]
# Batches:   0%|          | 0/71 [00:00<?, ?it/s]
# Batches:   0%|          | 0/71 [00:00<?, ?it/s]
# Batches:   0%|          | 0/71 [00:00<?, ?it/s]
# Epoch: 30
# Evaluating:   0%|          | 0/71 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/71 [00:00<?, ?it/s]
# [Valid]: Precision: 0.0436 Recall: 0.1507 NDCG: 0.1003 MRR: 0.1494
# [Test]: Precision: 0.0195 Recall: 0.1512 NDCG: 0.0767 MRR: 0.0783
# ------------------------------------------------------
# Batches:   0%|          | 0/71 [00:00<?, ?it/s]
# Batches:   0%|          | 0/71 [00:00<?, ?it/s]
# Batches:   0%|          | 0/71 [00:00<?, ?it/s]
# Batches:   0%|          | 0/71 [00:00<?, ?it/s]
# Batches:   0%|          | 0/71 [00:00<?, ?it/s]
# Epoch: 35
# Evaluating:   0%|          | 0/71 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/71 [00:00<?, ?it/s]
# [Valid]: Precision: 0.0439 Recall: 0.1515 NDCG: 0.1011 MRR: 0.1504
# [Test]: Precision: 0.0198 Recall: 0.1531 NDCG: 0.0776 MRR: 0.0787
# ------------------------------------------------------
# Batches:   0%|          | 0/71 [00:00<?, ?it/s]
# Batches:   0%|          | 0/71 [00:00<?, ?it/s]
# Batches:   0%|          | 0/71 [00:00<?, ?it/s]
# Batches:   0%|          | 0/71 [00:00<?, ?it/s]
# Batches:   0%|          | 0/71 [00:00<?, ?it/s]
# Epoch: 40
# Evaluating:   0%|          | 0/71 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/71 [00:00<?, ?it/s]
# [Valid]: Precision: 0.0413 Recall: 0.1424 NDCG: 0.0953 MRR: 0.1439
# [Test]: Precision: 0.0185 Recall: 0.1436 NDCG: 0.0731 MRR: 0.0751
# ------------------------------------------------------
# Batches:   0%|          | 0/71 [00:00<?, ?it/s]
# Batches:   0%|          | 0/71 [00:00<?, ?it/s]
# Batches:   0%|          | 0/71 [00:00<?, ?it/s]
# Batches:   0%|          | 0/71 [00:00<?, ?it/s]
# Batches:   0%|          | 0/71 [00:00<?, ?it/s]
# Epoch: 45
# Evaluating:   0%|          | 0/71 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/71 [00:00<?, ?it/s]
# [Valid]: Precision: 0.0421 Recall: 0.1457 NDCG: 0.0969 MRR: 0.1449
# [Test]: Precision: 0.0189 Recall: 0.1461 NDCG: 0.0739 MRR: 0.0753
# ------------------------------------------------------
# Batches:   0%|          | 0/71 [00:00<?, ?it/s]
# Batches:   0%|          | 0/71 [00:00<?, ?it/s]
# Batches:   0%|          | 0/71 [00:00<?, ?it/s]
# Batches:   0%|          | 0/71 [00:00<?, ?it/s]
# Batches:   0%|          | 0/71 [00:00<?, ?it/s]
# Epoch: 50
# Evaluating:   0%|          | 0/71 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/71 [00:00<?, ?it/s]
# [Valid]: Precision: 0.0425 Recall: 0.1467 NDCG: 0.0977 MRR: 0.146
# [Test]: Precision: 0.019 Recall: 0.1474 NDCG: 0.075 MRR: 0.0768
# ------------------------------------------------------
# Batches:   0%|          | 0/71 [00:00<?, ?it/s]
# Batches:   0%|          | 0/71 [00:00<?, ?it/s]
# Batches:   0%|          | 0/71 [00:00<?, ?it/s]
# Batches:   0%|          | 0/71 [00:00<?, ?it/s]
# ------------------
# Exiting from training early
# ======================================================
# End. Best Epoch 035
# [Valid]: Precision: 0.0439 Recall: 0.1515 NDCG: 0.1011 MRR: 0.1504
# [Test]: Precision: 0.0198 Recall: 0.1531 NDCG: 0.0776 MRR: 0.0787
# End time:  2026-04-16 19:06:21
# Best model saved to  ./saved_models/steam_lr0.0001_wd1e-05_bs512_ibs512_dims[1000, 1000]_emb12_x0_steps60_scale0.1_min1e-05_max0.02_sample0_reweightTrue_r1.pth

# %%
if __name__ == "__main__":
    # Make a Namespace class containing arguments for training
    args = Namespace(
        cuda = True, # Un-check this if there is no CUDA-supported device
        topN = "[20]", # Use Recall@20 only for validation
        dataset = "steam", 
        tst_w_val = True, # Use validation with training to predict test
        lr = 1e-4, # Learning rate
        weight_decay = 1e-5, # Model control coefficient
        batch_size = 512, # Batch size when training
        epochs = 1000,
        dims = "[1000, 1000]", # Underlying Denoising MLP model
        emb_size = 12, # Timestep-embedding, necessary for Diffusion model
        steps = 60, # Denoising steps
        noise_scale = 0.1, 
        noise_min = 1e-5,
        noise_max = 0.02,
        sampling_steps = 0, # No sampling in inference
        loss_logging = False, # Turn off epoch loss/cost results, producing clean log
        log_name = "r2"
    )
    train_model(args)
# Out:
# args: Namespace(dataset='steam', data_path='./datasets/', lr=0.0001, weight_decay=1e-05, batch_size=512, infer_batch_size=0, epochs=1000, topN='[20]', tst_w_val=True, cuda=True, gpu='0', save_path='./saved_models/', log_name='r2', round=1, loss_logging=False, time_type='cat', dims='[1000, 1000]', norm=False, emb_size=12, mean_type='x0', steps=60, noise_schedule='linear-var', noise_scale=0.1, noise_min=1e-05, noise_max=0.02, sampling_noise=False, sampling_steps=0, reweight=True)
# Starting time:  2026-04-16 20:33:41
# user num: 36321
# item num: 1980
# data ready.
# models ready.
# Number of all parameters: 5977136
# Start training...
# ======================================================
# Training:   0%|          | 0/1000 [00:00<?, ?it/s]
# Batches:   0%|          | 0/71 [00:00<?, ?it/s]
# Batches:   0%|          | 0/71 [00:00<?, ?it/s]
# Batches:   0%|          | 0/71 [00:00<?, ?it/s]
# Batches:   0%|          | 0/71 [00:00<?, ?it/s]
# Batches:   0%|          | 0/71 [00:00<?, ?it/s]
# Epoch: 5
# Evaluating:   0%|          | 0/71 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/71 [00:00<?, ?it/s]
# [Valid]: Precision: 0.037 Recall: 0.1279 NDCG: 0.0842 MRR: 0.1269
# [Test]: Precision: 0.0162 Recall: 0.1255 NDCG: 0.0631 MRR: 0.0645
# ------------------------------------------------------
# Batches:   0%|          | 0/71 [00:00<?, ?it/s]
# Batches:   0%|          | 0/71 [00:00<?, ?it/s]
# Batches:   0%|          | 0/71 [00:00<?, ?it/s]
# Batches:   0%|          | 0/71 [00:00<?, ?it/s]
# Batches:   0%|          | 0/71 [00:00<?, ?it/s]
# Epoch: 10
# Evaluating:   0%|          | 0/71 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/71 [00:00<?, ?it/s]
# [Valid]: Precision: 0.0411 Recall: 0.1419 NDCG: 0.0941 MRR: 0.1403
# [Test]: Precision: 0.0182 Recall: 0.1406 NDCG: 0.0715 MRR: 0.0736
# ------------------------------------------------------
# Batches:   0%|          | 0/71 [00:00<?, ?it/s]
# Batches:   0%|          | 0/71 [00:00<?, ?it/s]
# Batches:   0%|          | 0/71 [00:00<?, ?it/s]
# Batches:   0%|          | 0/71 [00:00<?, ?it/s]
# Batches:   0%|          | 0/71 [00:00<?, ?it/s]
# Epoch: 15
# Evaluating:   0%|          | 0/71 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/71 [00:00<?, ?it/s]
# [Valid]: Precision: 0.0419 Recall: 0.1444 NDCG: 0.0961 MRR: 0.1435
# [Test]: Precision: 0.0189 Recall: 0.1463 NDCG: 0.0742 MRR: 0.0755
# ------------------------------------------------------
# Batches:   0%|          | 0/71 [00:00<?, ?it/s]
# Batches:   0%|          | 0/71 [00:00<?, ?it/s]
# Batches:   0%|          | 0/71 [00:00<?, ?it/s]
# Batches:   0%|          | 0/71 [00:00<?, ?it/s]
# Batches:   0%|          | 0/71 [00:00<?, ?it/s]
# Epoch: 20
# Evaluating:   0%|          | 0/71 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/71 [00:00<?, ?it/s]
# [Valid]: Precision: 0.0422 Recall: 0.1461 NDCG: 0.0975 MRR: 0.1464
# [Test]: Precision: 0.0187 Recall: 0.1459 NDCG: 0.0743 MRR: 0.0762
# ------------------------------------------------------
# Batches:   0%|          | 0/71 [00:00<?, ?it/s]
# Batches:   0%|          | 0/71 [00:00<?, ?it/s]
# Batches:   0%|          | 0/71 [00:00<?, ?it/s]
# Batches:   0%|          | 0/71 [00:00<?, ?it/s]
# Batches:   0%|          | 0/71 [00:00<?, ?it/s]
# Epoch: 25
# Evaluating:   0%|          | 0/71 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/71 [00:00<?, ?it/s]
# [Valid]: Precision: 0.043 Recall: 0.1483 NDCG: 0.0989 MRR: 0.1477
# [Test]: Precision: 0.0191 Recall: 0.148 NDCG: 0.0753 MRR: 0.0771
# ------------------------------------------------------
# Batches:   0%|          | 0/71 [00:00<?, ?it/s]
# Batches:   0%|          | 0/71 [00:00<?, ?it/s]
# Batches:   0%|          | 0/71 [00:00<?, ?it/s]
# Batches:   0%|          | 0/71 [00:00<?, ?it/s]
# Batches:   0%|          | 0/71 [00:00<?, ?it/s]
# Epoch: 30
# Evaluating:   0%|          | 0/71 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/71 [00:00<?, ?it/s]
# [Valid]: Precision: 0.0436 Recall: 0.1507 NDCG: 0.1003 MRR: 0.1494
# [Test]: Precision: 0.0195 Recall: 0.1512 NDCG: 0.0767 MRR: 0.0783
# ------------------------------------------------------
# Batches:   0%|          | 0/71 [00:00<?, ?it/s]
# Batches:   0%|          | 0/71 [00:00<?, ?it/s]
# Batches:   0%|          | 0/71 [00:00<?, ?it/s]
# Batches:   0%|          | 0/71 [00:00<?, ?it/s]
# Batches:   0%|          | 0/71 [00:00<?, ?it/s]
# Epoch: 35
# Evaluating:   0%|          | 0/71 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/71 [00:00<?, ?it/s]
# [Valid]: Precision: 0.0439 Recall: 0.1515 NDCG: 0.1011 MRR: 0.1504
# [Test]: Precision: 0.0198 Recall: 0.1531 NDCG: 0.0776 MRR: 0.0787
# ------------------------------------------------------
# Batches:   0%|          | 0/71 [00:00<?, ?it/s]
# Batches:   0%|          | 0/71 [00:00<?, ?it/s]
# Batches:   0%|          | 0/71 [00:00<?, ?it/s]
# Batches:   0%|          | 0/71 [00:00<?, ?it/s]
# Batches:   0%|          | 0/71 [00:00<?, ?it/s]
# Epoch: 40
# Evaluating:   0%|          | 0/71 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/71 [00:00<?, ?it/s]
# [Valid]: Precision: 0.0413 Recall: 0.1424 NDCG: 0.0953 MRR: 0.1439
# [Test]: Precision: 0.0185 Recall: 0.1436 NDCG: 0.0731 MRR: 0.0751
# ------------------------------------------------------
# Batches:   0%|          | 0/71 [00:00<?, ?it/s]
# Batches:   0%|          | 0/71 [00:00<?, ?it/s]
# Batches:   0%|          | 0/71 [00:00<?, ?it/s]
# Batches:   0%|          | 0/71 [00:00<?, ?it/s]
# Batches:   0%|          | 0/71 [00:00<?, ?it/s]
# Epoch: 45
# Evaluating:   0%|          | 0/71 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/71 [00:00<?, ?it/s]
# [Valid]: Precision: 0.0421 Recall: 0.1457 NDCG: 0.0969 MRR: 0.1449
# [Test]: Precision: 0.0189 Recall: 0.1461 NDCG: 0.0739 MRR: 0.0753
# ------------------------------------------------------
# Batches:   0%|          | 0/71 [00:00<?, ?it/s]
# Batches:   0%|          | 0/71 [00:00<?, ?it/s]
# Batches:   0%|          | 0/71 [00:00<?, ?it/s]
# Batches:   0%|          | 0/71 [00:00<?, ?it/s]
# Batches:   0%|          | 0/71 [00:00<?, ?it/s]
# Epoch: 50
# Evaluating:   0%|          | 0/71 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/71 [00:00<?, ?it/s]
# [Valid]: Precision: 0.0425 Recall: 0.1467 NDCG: 0.0977 MRR: 0.146
# [Test]: Precision: 0.019 Recall: 0.1474 NDCG: 0.075 MRR: 0.0768
# ------------------------------------------------------
# Batches:   0%|          | 0/71 [00:00<?, ?it/s]
# Batches:   0%|          | 0/71 [00:00<?, ?it/s]
# Batches:   0%|          | 0/71 [00:00<?, ?it/s]
# Batches:   0%|          | 0/71 [00:00<?, ?it/s]
# ------------------
# Exiting from training early
# ======================================================
# End. Best Epoch 035
# [Valid]: Precision: 0.0439 Recall: 0.1515 NDCG: 0.1011 MRR: 0.1504
# [Test]: Precision: 0.0198 Recall: 0.1531 NDCG: 0.0776 MRR: 0.0787
# End time:  2026-04-16 20:46:35
# Best model saved to  ./saved_models/steam_lr0.0001_wd1e-05_bs512_ibs512_dims[1000, 1000]_emb12_x0_steps60_scale0.1_min1e-05_max0.02_sample0_reweightTrue_r2.pth

# %%
if __name__ == "__main__":
    # Make a Namespace class containing arguments for training
    args = Namespace(
        cuda = True, # Un-check this if there is no CUDA-supported device
        topN = "[20]", # Use Recall@20 only for validation
        dataset = "steam", 
        tst_w_val = True, # Use validation with training to predict test
        lr = 1e-4, # Learning rate
        weight_decay = 1e-5, # Model control coefficient
        batch_size = 512, # Batch size when training
        epochs = 1000,
        dims = "[1000, 1000]", # Underlying Denoising MLP model
        emb_size = 12, # Timestep-embedding, necessary for Diffusion model
        steps = 60, # Denoising steps
        noise_scale = 0.1, 
        noise_min = 1e-5,
        noise_max = 0.02,
        sampling_steps = 0, # No sampling in inference
        loss_logging = False, # Turn off epoch loss/cost results, producing clean log
        log_name = "r3"
    )
    train_model(args)
# Out:
# args: Namespace(dataset='steam', data_path='./datasets/', lr=0.0001, weight_decay=1e-05, batch_size=512, infer_batch_size=0, epochs=1000, topN='[20]', tst_w_val=True, cuda=True, gpu='0', save_path='./saved_models/', log_name='r3', round=1, loss_logging=False, time_type='cat', dims='[1000, 1000]', norm=False, emb_size=12, mean_type='x0', steps=60, noise_schedule='linear-var', noise_scale=0.1, noise_min=1e-05, noise_max=0.02, sampling_noise=False, sampling_steps=0, reweight=True)
# Starting time:  2026-04-16 20:46:35
# user num: 36321
# item num: 1980
# data ready.
# models ready.
# Number of all parameters: 5977136
# Start training...
# ======================================================
# Training:   0%|          | 0/1000 [00:00<?, ?it/s]
# Batches:   0%|          | 0/71 [00:00<?, ?it/s]
# Batches:   0%|          | 0/71 [00:00<?, ?it/s]
# Batches:   0%|          | 0/71 [00:00<?, ?it/s]
# Batches:   0%|          | 0/71 [00:00<?, ?it/s]
# Batches:   0%|          | 0/71 [00:00<?, ?it/s]
# Epoch: 5
# Evaluating:   0%|          | 0/71 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/71 [00:00<?, ?it/s]
# [Valid]: Precision: 0.037 Recall: 0.1279 NDCG: 0.0842 MRR: 0.1269
# [Test]: Precision: 0.0162 Recall: 0.1255 NDCG: 0.0631 MRR: 0.0645
# ------------------------------------------------------
# Batches:   0%|          | 0/71 [00:00<?, ?it/s]
# Batches:   0%|          | 0/71 [00:00<?, ?it/s]
# Batches:   0%|          | 0/71 [00:00<?, ?it/s]
# Batches:   0%|          | 0/71 [00:00<?, ?it/s]
# Batches:   0%|          | 0/71 [00:00<?, ?it/s]
# Epoch: 10
# Evaluating:   0%|          | 0/71 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/71 [00:00<?, ?it/s]
# [Valid]: Precision: 0.0411 Recall: 0.1419 NDCG: 0.0941 MRR: 0.1403
# [Test]: Precision: 0.0182 Recall: 0.1406 NDCG: 0.0715 MRR: 0.0736
# ------------------------------------------------------
# Batches:   0%|          | 0/71 [00:00<?, ?it/s]
# Batches:   0%|          | 0/71 [00:00<?, ?it/s]
# Batches:   0%|          | 0/71 [00:00<?, ?it/s]
# Batches:   0%|          | 0/71 [00:00<?, ?it/s]
# Batches:   0%|          | 0/71 [00:00<?, ?it/s]
# Epoch: 15
# Evaluating:   0%|          | 0/71 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/71 [00:00<?, ?it/s]
# [Valid]: Precision: 0.0419 Recall: 0.1444 NDCG: 0.0961 MRR: 0.1435
# [Test]: Precision: 0.0189 Recall: 0.1463 NDCG: 0.0742 MRR: 0.0755
# ------------------------------------------------------
# Batches:   0%|          | 0/71 [00:00<?, ?it/s]
# Batches:   0%|          | 0/71 [00:00<?, ?it/s]
# Batches:   0%|          | 0/71 [00:00<?, ?it/s]
# Batches:   0%|          | 0/71 [00:00<?, ?it/s]
# Batches:   0%|          | 0/71 [00:00<?, ?it/s]
# Epoch: 20
# Evaluating:   0%|          | 0/71 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/71 [00:00<?, ?it/s]
# [Valid]: Precision: 0.0422 Recall: 0.1461 NDCG: 0.0975 MRR: 0.1464
# [Test]: Precision: 0.0187 Recall: 0.1459 NDCG: 0.0743 MRR: 0.0762
# ------------------------------------------------------
# Batches:   0%|          | 0/71 [00:00<?, ?it/s]
# Batches:   0%|          | 0/71 [00:00<?, ?it/s]
# Batches:   0%|          | 0/71 [00:00<?, ?it/s]
# Batches:   0%|          | 0/71 [00:00<?, ?it/s]
# Batches:   0%|          | 0/71 [00:00<?, ?it/s]
# Epoch: 25
# Evaluating:   0%|          | 0/71 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/71 [00:00<?, ?it/s]
# [Valid]: Precision: 0.043 Recall: 0.1483 NDCG: 0.0989 MRR: 0.1477
# [Test]: Precision: 0.0191 Recall: 0.148 NDCG: 0.0753 MRR: 0.0771
# ------------------------------------------------------
# Batches:   0%|          | 0/71 [00:00<?, ?it/s]
# Batches:   0%|          | 0/71 [00:00<?, ?it/s]
# Batches:   0%|          | 0/71 [00:00<?, ?it/s]
# Batches:   0%|          | 0/71 [00:00<?, ?it/s]
# Batches:   0%|          | 0/71 [00:00<?, ?it/s]
# Epoch: 30
# Evaluating:   0%|          | 0/71 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/71 [00:00<?, ?it/s]
# [Valid]: Precision: 0.0436 Recall: 0.1507 NDCG: 0.1003 MRR: 0.1494
# [Test]: Precision: 0.0195 Recall: 0.1512 NDCG: 0.0767 MRR: 0.0783
# ------------------------------------------------------
# Batches:   0%|          | 0/71 [00:00<?, ?it/s]
# Batches:   0%|          | 0/71 [00:00<?, ?it/s]
# Batches:   0%|          | 0/71 [00:00<?, ?it/s]
# Batches:   0%|          | 0/71 [00:00<?, ?it/s]
# Batches:   0%|          | 0/71 [00:00<?, ?it/s]
# Epoch: 35
# Evaluating:   0%|          | 0/71 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/71 [00:00<?, ?it/s]
# [Valid]: Precision: 0.0439 Recall: 0.1515 NDCG: 0.1011 MRR: 0.1504
# [Test]: Precision: 0.0198 Recall: 0.1531 NDCG: 0.0776 MRR: 0.0787
# ------------------------------------------------------
# Batches:   0%|          | 0/71 [00:00<?, ?it/s]
# Batches:   0%|          | 0/71 [00:00<?, ?it/s]
# Batches:   0%|          | 0/71 [00:00<?, ?it/s]
# Batches:   0%|          | 0/71 [00:00<?, ?it/s]
# Batches:   0%|          | 0/71 [00:00<?, ?it/s]
# Epoch: 40
# Evaluating:   0%|          | 0/71 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/71 [00:00<?, ?it/s]
# [Valid]: Precision: 0.0413 Recall: 0.1424 NDCG: 0.0953 MRR: 0.1439
# [Test]: Precision: 0.0185 Recall: 0.1436 NDCG: 0.0731 MRR: 0.0751
# ------------------------------------------------------
# Batches:   0%|          | 0/71 [00:00<?, ?it/s]
# Batches:   0%|          | 0/71 [00:00<?, ?it/s]
# Batches:   0%|          | 0/71 [00:00<?, ?it/s]
# Batches:   0%|          | 0/71 [00:00<?, ?it/s]
# Batches:   0%|          | 0/71 [00:00<?, ?it/s]
# Epoch: 45
# Evaluating:   0%|          | 0/71 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/71 [00:00<?, ?it/s]
# [Valid]: Precision: 0.0421 Recall: 0.1457 NDCG: 0.0969 MRR: 0.1449
# [Test]: Precision: 0.0189 Recall: 0.1461 NDCG: 0.0739 MRR: 0.0753
# ------------------------------------------------------
# Batches:   0%|          | 0/71 [00:00<?, ?it/s]
# Batches:   0%|          | 0/71 [00:00<?, ?it/s]
# Batches:   0%|          | 0/71 [00:00<?, ?it/s]
# Batches:   0%|          | 0/71 [00:00<?, ?it/s]
# Batches:   0%|          | 0/71 [00:00<?, ?it/s]
# Epoch: 50
# Evaluating:   0%|          | 0/71 [00:00<?, ?it/s]
# Evaluating:   0%|          | 0/71 [00:00<?, ?it/s]
# [Valid]: Precision: 0.0425 Recall: 0.1467 NDCG: 0.0977 MRR: 0.146
# [Test]: Precision: 0.019 Recall: 0.1474 NDCG: 0.075 MRR: 0.0768
# ------------------------------------------------------
# Batches:   0%|          | 0/71 [00:00<?, ?it/s]
# Batches:   0%|          | 0/71 [00:00<?, ?it/s]
# Batches:   0%|          | 0/71 [00:00<?, ?it/s]
# Batches:   0%|          | 0/71 [00:00<?, ?it/s]
# ------------------
# Exiting from training early
# ======================================================
# End. Best Epoch 035
# [Valid]: Precision: 0.0439 Recall: 0.1515 NDCG: 0.1011 MRR: 0.1504
# [Test]: Precision: 0.0198 Recall: 0.1531 NDCG: 0.0776 MRR: 0.0787
# End time:  2026-04-16 20:59:50
# Best model saved to  ./saved_models/steam_lr0.0001_wd1e-05_bs512_ibs512_dims[1000, 1000]_emb12_x0_steps60_scale0.1_min1e-05_max0.02_sample0_reweightTrue_r3.pth
